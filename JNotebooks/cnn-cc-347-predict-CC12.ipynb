# %%
# %matplotlib inline
import matplotlib.pylab as plt
import numpy as np
import nibabel as nib
import os
import glob
import sys
import time
import siamxt

MY_UTILS_PATH = "../Modules/"
if not MY_UTILS_PATH in sys.path:
    sys.path.append(MY_UTILS_PATH)
import ipt_utils
import cnn_utils
import metrics_utils
# Out:
# Using TensorFlow backend.

# %%
orig_path = "/media/roberto/DATA/CC-359/Original/Original"
mask_path = "/media/roberto/DATA/GDrive/CC359_extra/Manual" 
mask_path2 = "/media/roberto/DATA/GDrive/CC359_extra/Manual-Julia"
staple_path = "/media/roberto/DATA/CC-359/STAPLE/STAPLE"

imgs_list = cc12_list =np.genfromtxt("../Data/cc12_orig.txt", dtype ="string")

masks_list = [os.path.join(mask_path,f.split(".")[0]+"_manual.nii.gz") for f in imgs_list]
masks_list2 = [os.path.join(mask_path2,f.split(".")[0]+"_man_julia.nii.gz") for f in imgs_list]
staple_list = [os.path.join(staple_path,f.split(".")[0]+"_staple.nii.gz") for f in imgs_list]
imgs_list = [os.path.join(orig_path,f) for f in imgs_list]
print imgs_list[0]
print masks_list[0]
print masks_list2[0]
print staple_list[0]


stats = np.load("../Data/ss_unet_cc347.npy")
mean = stats[0]
std = stats[1]

model_path = "../Data/ss_unet_cc_347_best.hdf5"
dice = np.zeros((12,3))
Bc = np.ones((3,3,3),dtype = bool)
# Out:
# /media/roberto/DATA/CC-359/Original/Original/CC0003_philips_15_63_F.nii.gz
# /media/roberto/DATA/GDrive/CC359_extra/Manual/CC0003_philips_15_63_F_manual.nii.gz
# /media/roberto/DATA/GDrive/CC359_extra/Manual-Julia/CC0003_philips_15_63_F_man_julia.nii.gz
# /media/roberto/DATA/CC-359/STAPLE/STAPLE/CC0003_philips_15_63_F_staple.nii.gz

# %%
model = cnn_utils.get_unet_mod()
model.load_weights(model_path)
for ii in xrange(len(imgs_list)):
    img = nib.load(imgs_list[ii])
    img = img.get_data()
    img = img.transpose(1,0,2)
    img_min = img.min()
    img_max = img.max()
    img_norm = 1.0*(img - img_min)/(img_max-img_min)
    img_norm -= mean
    img_norm /= std
    x,y,z = img_norm.shape
    img_rgb = np.zeros((x-2,y,z,3))
    img_rgb[:,:,:,0] = img_norm[0:-2,:,:]
    img_rgb[:,:,:,1] = img_norm[1:-1,:,:]
    img_rgb[:,:,:,2] = img_norm[2:,:,:]
    img_rgb,nw,nz  = cnn_utils.pad_images(img_rgb)
    predict = model.predict(img_rgb)
    predict = predict[:,:-nw,:-nz,0]
    predict2 = np.zeros((x,y,z))
    predict2[1:-1,:,:] = predict
    predict2 = (predict2 >0.5).astype(np.uint8)
    mxt = siamxt.MaxTreeAlpha(predict2,Bc)
    area_max = mxt.node_array[3,1:].max() 
    mxt.areaOpen(area_max - 1)
    predict3 = mxt.getImage() > 0.5
    H,W,Z = img_norm.shape
    plt.figure()
    plt.subplot(131)
    plt.imshow(img_norm[H/2,:,:], cmap = 'gray')
    plt.imshow(predict3[H/2,:,:], cmap = 'cool',alpha = 0.2)
    plt.axis("off")
    plt.subplot(132)
    plt.imshow(img_norm[:,W/2,:], cmap = 'gray')
    plt.imshow(predict3[:,W/2,:], cmap = 'cool',alpha = 0.2)
    plt.axis("off")
    plt.subplot(133)
    plt.imshow(img_norm[:,:,Z/2], cmap = 'gray')
    plt.imshow(predict3[:,:,Z/2], cmap = 'cool',alpha = 0.2)
    plt.axis("off")
    plt.show()
    
    #ipt_utils.save_seg(predict2,affine,os.path.join("./Predict/",prefixes[ii] + "_cnn.nii.gz"))
    mask_rob = nib.load(masks_list[ii]).get_data().transpose(1,0,2)>0.5
    dice[ii,0] = metrics_utils.dice(mask_rob,predict3)  
    mask_julia = nib.load(masks_list2[ii]).get_data().transpose(1,0,2)>0.5
    dice[ii,1] = metrics_utils.dice(mask_julia,predict3)
    mask_staple = nib.load(staple_list[ii]).get_data().transpose(1,0,2)>0.5
    dice[ii,2] = metrics_utils.dice(mask_staple,predict3)

print "Average dice and standrd deviation"    
print dice.mean(axis = 0)    
print dice.std(axis = 0)
# Out:
# Average dice and standrd deviation
# [ 0.97142647  0.95896212  0.98714628]
# [ 0.00572754  0.01272477  0.00365825]
