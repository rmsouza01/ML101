# %% [markdown]
# # Compressed Sensing MR - CNN Training
#
# In this notebook we are going to train a CNN to perform compressed sensing. In this illustration we extract patches using the [Calgary-Campinas-347](http://miclab.fee.unicamp.br/tools) public dataset.
#
# The goal of this tutorial is:
#  - Illustrate how to to train a CNN for compressed sensing.

# %%
# %matplotlib inline
import matplotlib.pylab as plt
import numpy as np
import nibabel as nib
import os
import glob
import sys
import random
import time

from keras.callbacks import ModelCheckpoint, EarlyStopping

MY_UTILS_PATH = "../Modules/"
if not MY_UTILS_PATH in sys.path:
    sys.path.append(MY_UTILS_PATH)
import cnn_utils
# Out:
# Using TensorFlow backend.

# %%
patches_path = "/media/roberto/DATA/CS-CC347"
max_value = 1000.0
#Loading data
data = np.load(os.path.join(patches_path,"cs_cc347_orig_uniform_25.npy")).astype(float)/max_value
data_under = np.load(os.path.join(patches_path,"cs_cc347_under_uniform_25.npy")).astype(float)/max_value

# Splitting into development and test set
n = int(data.shape[0]*0.3)
data_train = data[:-n]
data_test = data[-n:]
data_train_under = data_under[:-n]
data_test_under = data_under[-n:]

#Shuffling samples
indexes = np.arange(0,data_train.shape[0],dtype = int)
np.random.shuffle(indexes)
data_train = data_train[indexes]
data_train_under = data_train_under[indexes]

# %%
print data_train.shape
print data_test.shape
# Early stopping callback to shut down training after 10 epochs with no improvement
earlyStopping = EarlyStopping(monitor='mean_absolute_error',
                                        patience=5, 
                                        verbose=1, mode='min')
# Checkpoint callback to save model after each improvement along the epochs
checkpoint = ModelCheckpoint('cnn_cs_best_uniform_25.hdf5', mode = 'min', monitor='mean_absolute_error'
                            ,verbose=0, save_best_only=True, save_weights_only = True)

model = cnn_utils.get_unet_mod_reg((256,256),nchannels = 1,\
                                   learning_rate = 1e-3,\
                                   learning_decay =1e-6)   
#model.load_weights('cnn_cs_2x_best.hdf5')
print model.summary()
# Out:
# (4858, 256, 256)
# (2082, 256, 256)
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 256, 256, 1)   0
# ____________________________________________________________________________________________________
# gaussian_noise_1 (GaussianNoise) (None, 256, 256, 1)   0           input_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 256, 256, 32)  320         gaussian_noise_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 256, 256, 32)  9248        conv2d_1[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)   (None, 128, 128, 32)  0           conv2d_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 128, 128, 64)  18496       max_pooling2d_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 128, 128, 64)  36928       conv2d_3[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)   (None, 64, 64, 64)    0           conv2d_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 64, 64, 128)   73856       max_pooling2d_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 64, 64, 128)   147584      conv2d_5[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)   (None, 32, 32, 128)   0           conv2d_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 32, 32, 256)   295168      max_pooling2d_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 32, 32, 256)   590080      conv2d_7[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)   (None, 16, 16, 256)   0           conv2d_8[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 16, 16, 256)   0           max_pooling2d_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 16, 16, 512)   1180160     dropout_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 16, 16, 512)   2359808     conv2d_9[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)   (None, 32, 32, 512)   0           conv2d_10[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 32, 32, 768)   0           up_sampling2d_1[0][0]
#                                                                    conv2d_8[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 32, 32, 768)   0           concatenate_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 32, 32, 256)   1769728     dropout_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 32, 32, 256)   590080      conv2d_11[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)   (None, 64, 64, 256)   0           conv2d_12[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 64, 64, 384)   0           up_sampling2d_2[0][0]
#                                                                    conv2d_6[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 64, 64, 384)   0           concatenate_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 64, 64, 128)   442496      dropout_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 64, 64, 128)   147584      conv2d_13[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)   (None, 128, 128, 128) 0           conv2d_14[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, 128, 128, 192) 0           up_sampling2d_3[0][0]
#                                                                    conv2d_4[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 128, 128, 192) 0           concatenate_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 128, 128, 64)  110656      dropout_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 128, 128, 64)  36928       conv2d_15[0][0]
# ____________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)   (None, 256, 256, 64)  0           conv2d_16[0][0]
# ____________________________________________________________________________________________________
# concatenate_4 (Concatenate)      (None, 256, 256, 96)  0           up_sampling2d_4[0][0]
#                                                                    conv2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)              (None, 256, 256, 96)  0           concatenate_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 256, 256, 32)  27680       dropout_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_18 (Conv2D)               (None, 256, 256, 32)  9248        conv2d_17[0][0]
# ____________________________________________________________________________________________________
# conv2d_19 (Conv2D)               (None, 256, 256, 1)   33          conv2d_18[0][0]
# ====================================================================================================
# Total params: 7,846,081
# Trainable params: 7,846,081
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# None

# %%
hist = model.fit(data_train_under[:,:,:,np.newaxis],data_train[:,:,:,np.newaxis],epochs=80,
                 batch_size=16,
                 verbose=1,
                 validation_split=0.3,callbacks=[checkpoint,earlyStopping])
# Out:
# Train on 3400 samples, validate on 1458 samples
# Epoch 1/80
# 3400/3400 [==============================] - 146s - loss: 0.0280 - mean_absolute_error: 0.0280 - val_loss: 0.0130 - val_mean_absolute_error: 0.0130
# Epoch 2/80
# 3400/3400 [==============================] - 140s - loss: 0.0146 - mean_absolute_error: 0.0146 - val_loss: 0.0125 - val_mean_absolute_error: 0.0125
# Epoch 3/80
# 3400/3400 [==============================] - 140s - loss: 0.0139 - mean_absolute_error: 0.0139 - val_loss: 0.0120 - val_mean_absolute_error: 0.0120
# Epoch 4/80
# 3400/3400 [==============================] - 141s - loss: 0.0134 - mean_absolute_error: 0.0134 - val_loss: 0.0117 - val_mean_absolute_error: 0.0117
# Epoch 5/80
# 3400/3400 [==============================] - 141s - loss: 0.0130 - mean_absolute_error: 0.0130 - val_loss: 0.0135 - val_mean_absolute_error: 0.0135
# Epoch 6/80
# 3400/3400 [==============================] - 141s - loss: 0.0125 - mean_absolute_error: 0.0125 - val_loss: 0.0114 - val_mean_absolute_error: 0.0114
# Epoch 7/80
# 3400/3400 [==============================] - 147s - loss: 0.0121 - mean_absolute_error: 0.0121 - val_loss: 0.0113 - val_mean_absolute_error: 0.0113
# Epoch 8/80
# 3400/3400 [==============================] - 148s - loss: 0.0117 - mean_absolute_error: 0.0117 - val_loss: 0.0114 - val_mean_absolute_error: 0.0114
# Epoch 9/80
# 3400/3400 [==============================] - 148s - loss: 0.0114 - mean_absolute_error: 0.0114 - val_loss: 0.0114 - val_mean_absolute_error: 0.0114
# Epoch 10/80
# 3400/3400 [==============================] - 148s - loss: 0.0111 - mean_absolute_error: 0.0111 - val_loss: 0.0106 - val_mean_absolute_error: 0.0106
# Epoch 11/80
# 3400/3400 [==============================] - 148s - loss: 0.0111 - mean_absolute_error: 0.0111 - val_loss: 0.0103 - val_mean_absolute_error: 0.0103
# Epoch 12/80
# 3400/3400 [==============================] - 148s - loss: 0.0109 - mean_absolute_error: 0.0109 - val_loss: 0.0099 - val_mean_absolute_error: 0.0099
# Epoch 13/80
# 3400/3400 [==============================] - 148s - loss: 0.0106 - mean_absolute_error: 0.0106 - val_loss: 0.0102 - val_mean_absolute_error: 0.0102
# Epoch 14/80
# 3400/3400 [==============================] - 148s - loss: 0.0106 - mean_absolute_error: 0.0106 - val_loss: 0.0098 - val_mean_absolute_error: 0.0098
# Epoch 15/80
# 3400/3400 [==============================] - 148s - loss: 0.0106 - mean_absolute_error: 0.0106 - val_loss: 0.0100 - val_mean_absolute_error: 0.0100
# Epoch 16/80
# 3400/3400 [==============================] - 148s - loss: 0.0102 - mean_absolute_error: 0.0102 - val_loss: 0.0094 - val_mean_absolute_error: 0.0094
# Epoch 17/80
# 3400/3400 [==============================] - 147s - loss: 0.0103 - mean_absolute_error: 0.0103 - val_loss: 0.0102 - val_mean_absolute_error: 0.0102
# Epoch 18/80
# 3400/3400 [==============================] - 148s - loss: 0.0101 - mean_absolute_error: 0.0101 - val_loss: 0.0098 - val_mean_absolute_error: 0.0098
# Epoch 19/80
# 3400/3400 [==============================] - 147s - loss: 0.0102 - mean_absolute_error: 0.0102 - val_loss: 0.0100 - val_mean_absolute_error: 0.0100
# Epoch 20/80
# 3400/3400 [==============================] - 148s - loss: 0.0101 - mean_absolute_error: 0.0101 - val_loss: 0.0097 - val_mean_absolute_error: 0.0097
# Epoch 21/80
# 3400/3400 [==============================] - 148s - loss: 0.0100 - mean_absolute_error: 0.0100 - val_loss: 0.0094 - val_mean_absolute_error: 0.0094
# Epoch 22/80
# 3400/3400 [==============================] - 147s - loss: 0.0102 - mean_absolute_error: 0.0102 - val_loss: 0.0094 - val_mean_absolute_error: 0.0094
# Epoch 23/80
# 3400/3400 [==============================] - 148s - loss: 0.0099 - mean_absolute_error: 0.0099 - val_loss: 0.0090 - val_mean_absolute_error: 0.0090
# Epoch 24/80
# 3400/3400 [==============================] - 147s - loss: 0.0099 - mean_absolute_error: 0.0099 - val_loss: 0.0092 - val_mean_absolute_error: 0.0092
# Epoch 25/80
# 3400/3400 [==============================] - 148s - loss: 0.0098 - mean_absolute_error: 0.0098 - val_loss: 0.0093 - val_mean_absolute_error: 0.0093
# Epoch 26/80
# 3400/3400 [==============================] - 148s - loss: 0.0098 - mean_absolute_error: 0.0098 - val_loss: 0.0093 - val_mean_absolute_error: 0.0093
# Epoch 27/80
# 3400/3400 [==============================] - 148s - loss: 0.0097 - mean_absolute_error: 0.0097 - val_loss: 0.0106 - val_mean_absolute_error: 0.0106
# Epoch 28/80
# 3400/3400 [==============================] - 147s - loss: 0.0097 - mean_absolute_error: 0.0097 - val_loss: 0.0094 - val_mean_absolute_error: 0.0094
# Epoch 29/80
# 3400/3400 [==============================] - 148s - loss: 0.0096 - mean_absolute_error: 0.0096 - val_loss: 0.0090 - val_mean_absolute_error: 0.0090
# Epoch 30/80
# 3400/3400 [==============================] - 147s - loss: 0.0096 - mean_absolute_error: 0.0096 - val_loss: 0.0093 - val_mean_absolute_error: 0.0093
# Epoch 31/80
# 3400/3400 [==============================] - 147s - loss: 0.0096 - mean_absolute_error: 0.0096 - val_loss: 0.0097 - val_mean_absolute_error: 0.0097
# Epoch 32/80
# 3400/3400 [==============================] - 148s - loss: 0.0096 - mean_absolute_error: 0.0096 - val_loss: 0.0091 - val_mean_absolute_error: 0.0091
# Epoch 33/80
# 3400/3400 [==============================] - 148s - loss: 0.0095 - mean_absolute_error: 0.0095 - val_loss: 0.0092 - val_mean_absolute_error: 0.0092
# Epoch 34/80
# 3400/3400 [==============================] - 147s - loss: 0.0096 - mean_absolute_error: 0.0096 - val_loss: 0.0092 - val_mean_absolute_error: 0.0092
# Epoch 35/80
# 3400/3400 [==============================] - 148s - loss: 0.0095 - mean_absolute_error: 0.0095 - val_loss: 0.0092 - val_mean_absolute_error: 0.0092
# Epoch 36/80
# 3400/3400 [==============================] - 142s - loss: 0.0095 - mean_absolute_error: 0.0095 - val_loss: 0.0100 - val_mean_absolute_error: 0.0100
# Epoch 37/80
# 3400/3400 [==============================] - 141s - loss: 0.0095 - mean_absolute_error: 0.0095 - val_loss: 0.0092 - val_mean_absolute_error: 0.0092
# Epoch 38/80
# 3400/3400 [==============================] - 141s - loss: 0.0096 - mean_absolute_error: 0.0096 - val_loss: 0.0098 - val_mean_absolute_error: 0.0098
# Epoch 39/80
# 3400/3400 [==============================] - 142s - loss: 0.0095 - mean_absolute_error: 0.0095 - val_loss: 0.0085 - val_mean_absolute_error: 0.0085
# Epoch 40/80
# 3400/3400 [==============================] - 142s - loss: 0.0094 - mean_absolute_error: 0.0094 - val_loss: 0.0092 - val_mean_absolute_error: 0.0092
# Epoch 41/80
# 3400/3400 [==============================] - 142s - loss: 0.0093 - mean_absolute_error: 0.0093 - val_loss: 0.0089 - val_mean_absolute_error: 0.0089
# Epoch 42/80
# 3400/3400 [==============================] - 142s - loss: 0.0093 - mean_absolute_error: 0.0093 - val_loss: 0.0093 - val_mean_absolute_error: 0.0093
# Epoch 43/80
# 3400/3400 [==============================] - 141s - loss: 0.0094 - mean_absolute_error: 0.0094 - val_loss: 0.0100 - val_mean_absolute_error: 0.0100
# Epoch 44/80
# 3400/3400 [==============================] - 141s - loss: 0.0094 - mean_absolute_error: 0.0094 - val_loss: 0.0091 - val_mean_absolute_error: 0.0091
# Epoch 45/80
# 3400/3400 [==============================] - 142s - loss: 0.0092 - mean_absolute_error: 0.0092 - val_loss: 0.0088 - val_mean_absolute_error: 0.0088
# Epoch 46/80
# 3400/3400 [==============================] - 141s - loss: 0.0094 - mean_absolute_error: 0.0094 - val_loss: 0.0089 - val_mean_absolute_error: 0.0089
# Epoch 47/80
# 3400/3400 [==============================] - 141s - loss: 0.0093 - mean_absolute_error: 0.0093 - val_loss: 0.0094 - val_mean_absolute_error: 0.0094
# Epoch 48/80
# 3400/3400 [==============================] - 141s - loss: 0.0094 - mean_absolute_error: 0.0094 - val_loss: 0.0091 - val_mean_absolute_error: 0.0091
# Epoch 49/80
# 3400/3400 [==============================] - 142s - loss: 0.0092 - mean_absolute_error: 0.0092 - val_loss: 0.0094 - val_mean_absolute_error: 0.0094
# Epoch 50/80
# 3400/3400 [==============================] - 141s - loss: 0.0092 - mean_absolute_error: 0.0092 - val_loss: 0.0090 - val_mean_absolute_error: 0.0090
# Epoch 51/80
# 3400/3400 [==============================] - 141s - loss: 0.0092 - mean_absolute_error: 0.0092 - val_loss: 0.0093 - val_mean_absolute_error: 0.0093
# Epoch 52/80
# 3400/3400 [==============================] - 140s - loss: 0.0092 - mean_absolute_error: 0.0092 - val_loss: 0.0102 - val_mean_absolute_error: 0.0102
# Epoch 53/80
# 3400/3400 [==============================] - 140s - loss: 0.0091 - mean_absolute_error: 0.0091 - val_loss: 0.0094 - val_mean_absolute_error: 0.0094
# Epoch 54/80
# 3400/3400 [==============================] - 140s - loss: 0.0091 - mean_absolute_error: 0.0091 - val_loss: 0.0106 - val_mean_absolute_error: 0.0106
# Epoch 55/80
# 3400/3400 [==============================] - 140s - loss: 0.0091 - mean_absolute_error: 0.0091 - val_loss: 0.0112 - val_mean_absolute_error: 0.0112
# Epoch 56/80
# 3400/3400 [==============================] - 140s - loss: 0.0091 - mean_absolute_error: 0.0091 - val_loss: 0.0104 - val_mean_absolute_error: 0.0104
# Epoch 57/80
# 3400/3400 [==============================] - 140s - loss: 0.0092 - mean_absolute_error: 0.0092 - val_loss: 0.0111 - val_mean_absolute_error: 0.0111
# Epoch 58/80
# 3400/3400 [==============================] - 140s - loss: 0.0090 - mean_absolute_error: 0.0090 - val_loss: 0.0107 - val_mean_absolute_error: 0.0107
# Epoch 59/80
# 3400/3400 [==============================] - 140s - loss: 0.0091 - mean_absolute_error: 0.0091 - val_loss: 0.0103 - val_mean_absolute_error: 0.0103
# Epoch 60/80
# 3400/3400 [==============================] - 140s - loss: 0.0090 - mean_absolute_error: 0.0090 - val_loss: 0.0104 - val_mean_absolute_error: 0.0104
# Epoch 61/80
# 3400/3400 [==============================] - 140s - loss: 0.0090 - mean_absolute_error: 0.0090 - val_loss: 0.0126 - val_mean_absolute_error: 0.0126
# Epoch 62/80
# 3400/3400 [==============================] - 140s - loss: 0.0091 - mean_absolute_error: 0.0091 - val_loss: 0.0116 - val_mean_absolute_error: 0.0116
# Epoch 63/80
# 3400/3400 [==============================] - 140s - loss: 0.0090 - mean_absolute_error: 0.0090 - val_loss: 0.0132 - val_mean_absolute_error: 0.0132
# Epoch 64/80
# 3400/3400 [==============================] - 140s - loss: 0.0090 - mean_absolute_error: 0.0090 - val_loss: 0.0121 - val_mean_absolute_error: 0.0121
# Epoch 65/80
# 3400/3400 [==============================] - 140s - loss: 0.0090 - mean_absolute_error: 0.0090 - val_loss: 0.0126 - val_mean_absolute_error: 0.0126
# Epoch 66/80
# 3400/3400 [==============================] - 140s - loss: 0.0089 - mean_absolute_error: 0.0089 - val_loss: 0.0136 - val_mean_absolute_error: 0.0136
# Epoch 67/80
# 3400/3400 [==============================] - 140s - loss: 0.0090 - mean_absolute_error: 0.0090 - val_loss: 0.0122 - val_mean_absolute_error: 0.0122
# Epoch 68/80
# 3400/3400 [==============================] - 140s - loss: 0.0089 - mean_absolute_error: 0.0089 - val_loss: 0.0122 - val_mean_absolute_error: 0.0122
# Epoch 69/80
# 3400/3400 [==============================] - 140s - loss: 0.0089 - mean_absolute_error: 0.0089 - val_loss: 0.0139 - val_mean_absolute_error: 0.0139
# Epoch 70/80
# 3400/3400 [==============================] - 140s - loss: 0.0089 - mean_absolute_error: 0.0089 - val_loss: 0.0132 - val_mean_absolute_error: 0.0132
# Epoch 71/80
# 3400/3400 [==============================] - 140s - loss: 0.0089 - mean_absolute_error: 0.0089 - val_loss: 0.0116 - val_mean_absolute_error: 0.0116
# Epoch 72/80
# 3400/3400 [==============================] - 140s - loss: 0.0089 - mean_absolute_error: 0.0089 - val_loss: 0.0152 - val_mean_absolute_error: 0.0152
# Epoch 73/80
# 3400/3400 [==============================] - 140s - loss: 0.0089 - mean_absolute_error: 0.0089 - val_loss: 0.0143 - val_mean_absolute_error: 0.0143
# Epoch 74/80
# 3400/3400 [==============================] - 140s - loss: 0.0088 - mean_absolute_error: 0.0088 - val_loss: 0.0149 - val_mean_absolute_error: 0.0149
# Epoch 75/80
# 3400/3400 [==============================] - 140s - loss: 0.0088 - mean_absolute_error: 0.0088 - val_loss: 0.0148 - val_mean_absolute_error: 0.0148
# Epoch 76/80
# 3400/3400 [==============================] - 140s - loss: 0.0089 - mean_absolute_error: 0.0089 - val_loss: 0.0135 - val_mean_absolute_error: 0.0135
# Epoch 77/80
# 3400/3400 [==============================] - 140s - loss: 0.0088 - mean_absolute_error: 0.0088 - val_loss: 0.0153 - val_mean_absolute_error: 0.0153
# Epoch 78/80
# 3400/3400 [==============================] - 140s - loss: 0.0088 - mean_absolute_error: 0.0088 - val_loss: 0.0145 - val_mean_absolute_error: 0.0145
# Epoch 79/80
# 3400/3400 [==============================] - 140s - loss: 0.0088 - mean_absolute_error: 0.0088 - val_loss: 0.0146 - val_mean_absolute_error: 0.0146
# Epoch 80/80
# 3400/3400 [==============================] - 140s - loss: 0.0088 - mean_absolute_error: 0.0088 - val_loss: 0.0151 - val_mean_absolute_error: 0.0151

# %%
np.save(os.path.join(patches_path,"cs_cc347_train_uniform_25.npy"),(data_train*1000).astype(np.uint16))
np.save(os.path.join(patches_path,"cs_cc347_train_under_uniform_25.npy"),(data_train_under*1000).astype(np.uint16))
np.save(os.path.join(patches_path,"cs_cc347_test_uniform_25.npy"),(data_test*1000).astype(np.uint16))
np.save(os.path.join(patches_path,"cs_cc347_test_uniform_25.npy"),(data_test_under*1000).astype(np.uint16))

# %%
model = cnn_utils.get_unet_mod_reg((256,256),nchannels = 1,\
                                   learning_rate = 1e-3,\
                                   learning_decay =5e-6)   
model.load_weights('cnn_cs_best_uniform_25.hdf5')
predict = model.predict(data_test_under[:,:,:,np.newaxis])[:,:,:,0]
error = np.abs(predict-data_test).mean()
print error
print data_test.mean()
# Out:
# 0.0140168903671
# 0.0840375355511

# %%
plt.figure()
plt.scatter(np.arange(data_test.shape[0]),np.abs(predict-data_test).mean(axis = (1,2))/data_test.mean())
plt.grid()
plt.show()

# %%
nb = 200
print nb
plt.figure(dpi = 300)
plt.subplot(131)
plt.imshow(data_test[nb],cmap = 'gray')
plt.axis("off")
plt.subplot(132)
plt.imshow(data_test_under[nb],cmap = 'gray')
plt.axis("off")
plt.subplot(133)
plt.imshow(predict[nb],cmap = 'gray')
plt.axis("off")
plt.show()
# Out:
# 200
